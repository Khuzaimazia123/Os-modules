# %%
import os
create_folder = "my 3folder"
os.mkdir(create_folder)
print ("Folder, {create_folder} has been created.")

current_folder = os.getcwd()
print ("Current Working Directory:",current_folder)

import math
number = 82
square_root = math.sqrt(number)
print (f"Square root of {number} is: {square_root}")

import math
Radius = 56
area = math.pi*Radius**2
print (f"The area of radius {Radius} is: {area}")
print (math.pi)
# Out:
# Folder, {create_folder} has been created.
# Current Working Directory: /content
# Square root of 82 is: 9.055385138137417
# The area of radius 56 is: 9852.03456165759
# 3.141592653589793
